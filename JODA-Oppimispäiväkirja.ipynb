# %% [markdown]
# # Viikko 1
# ## 1
# Osallistuin viikon opetukseen ja demo-luentoon. Käytin tämän dokumentin tekoon pääasiallisesti luentomateriaaleja sekä flippausvinkin artikkelia.
#
#
# ## 2 Tiivistelmä luentoviikon keskeisistä asioista
# Tunnilla käytiin aluksi läpi kurssin suorittamiseen liittyvät asiat. Tämän jälkeen esiteltiin sitä, mitä datatieteilijä tekee ja mistä osa-alueista datatieteilijän taidot koostuvat. Venn-diagrammia käytettiin tämän havainnollistamiseen, joka auttoi hahmottamaan eri osa-alueiden välisiä leikkauskohtia. Diagrammi auttoi minua myös huomaamaan, että tilastotieteen ja ohjelmoinnin (jotka ovat olleet taitoja joita olen kehittänyt pääsääntöisesti opiskeluissani) ohella myös liiketalouden osaaminen kuuluu keskeisesti datatieteilijän taitoihin.
#
# Luennolla käytiin myös läpi datatieteessä usein käytettyjä kieliä, joista Python nostettiin tärkeimmäksi. Tästä olen myös samaa mieltä, että vaikka esimerkiksi R:llä on oma paikkansa, on Python paljon monipuolisempi. Toisaalta kuten flippausvinkki 1 artikkelissa todettiin tärkeää ei ole kieli vaan datatieteen oppiminen konkreettisten projektien kautta ja että kielen valintaan voi vaikuttaa myös oppijan tausta, eli esimerkiksi "tieteellistä ohjelmointia" MATLAB:illa tehneelle henkilölle voi olla helpompaa ottaa aluksi R haltuun.
#
# Seuraavaksi esiteltiin yleisesti datatieteen työssä läpikäytäviä vaiheita kiinnostavien hypoteesejen luomisesta datan keräämisen, valmistelemisen ja mallintamisen kautta evaluointiin.
#
# Lopussa käytiin läpi datan määrän kasvun vaikutuksia, big datan määritelmää ja kuinka se eroaa data-analyysistä, sekä pandas-kirjaston alkeita, joka oli itselleni jo hieman tuttu tilastotieteen kursseilta.
#
# ## 3 Tärkeimmät oppimani asiat
# -Liiketalouden osa-alueen tärkeys
# -Datatieteen laajuus (luennolla esitelty kartta)
# -Big datan ja data-analyysin välisiä eroja (esim. big datassa suurin osa ajasta menee datan "siivoamiseen")
# -Jupyter Notebook
# -Huomio siitä, kuinka suureen dataan käsiksi pääsy voi olla usein yksityiselle henkilölle tai pienelle yritykselle vaikeaa
#
# ## 4 Flippausvinkkejä
# Vinkki 1: https://towardsdatascience.com/python-vs-r-for-data-science-cf2699dfff4b <-- artikkeli joka käsittelee Python vs. R datatieteessä.
#
# ## 5 Koodia

# %%
import pandas as pd
url = 'https://github.com/Isildur-sys/JODA-Pvkirja/raw/main/data/listings.csv'
df = pd.read_csv(url)
df.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0  10595             96m2, 3BR, 2BA, Metro, WI-FI etc...    37177  Emmanouil
# 1  10990    Athens Quality Apartments - Deluxe Apartment    37177  Emmanouil
# 2  10993              Athens Quality Apartments - Studio    37177  Emmanouil
# 3  10995  AQA-No2 1-bedroom, smart tv, fiber connection,    37177  Emmanouil
# 4  27262              54m2, 1-br, cable tv, wi-fi, metro    37177  Emmanouil
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98863   23.76527  Entire home/apt
# 1                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 2                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98888   23.76473  Entire home/apt
# 3                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 4                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500  Entire home/apt
#
# ...
